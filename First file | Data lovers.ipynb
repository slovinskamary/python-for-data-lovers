# %% [markdown]
# **First file**

# %% [markdown]
# # Start

# %% [markdown]
# I am **Mariia** and
# I am trying to code on *Python*

# %%
print('Hello world!')
# Out:
# Hello world!

# %%
7+114
# Out:
# 121

# %% [markdown]
# ## Розділ 1
# просто собі текст
#
# ### Підрозділ 1
#
# ## Розділ 2

# %%
import time

for i in range(9):
    print(i)
    time.sleep(29)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
my_list = [1, 2, 3, 4]

# %% [markdown]
# В мене є список
# * Один
#     - підсписок
#         - це
#   - інший підписок
#         - то
#         - і ще то
# * два
#   - підсписок

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot(np.sin(range(50)));

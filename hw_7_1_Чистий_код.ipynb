# %% [markdown]
# У завданнях 1-4. Вам наданий простий код на Python, який не відповідає вказівкам PEP8. Ваше завдання — відредагувати код так, аби він відповідав PEP8. Напишіть після редагуванню коду, дотримання яких правил з pep8 ви досягли в відредагованій версі, наприклад
# ```
# - додала пробіли навколо бінарного оператора
# - додала два порожні рядки між визначеннями функцій
# і тд
# ```
# Також можна зазанчити використані правила коментарями по коду, а не окремим повідомленням.
#
# Відредагований код має виконувати весь той самий функціонал, але бути написаний відповідно до вимог до гарного коду на Python! Не забудьте запустити відредагований код, він має бути робочим.

# %% [markdown]
# Завдання 1.

# %%
def greet(name):print(f"Hello, {name}")
def add(n1,n2):return n1+n2

x = 5;y = 3
display(greet("John"),add(x,y))
# Out:
# Hello, John
# None
# 8

# %%
def greet(name):
    """Prints a greeting message."""  #можна додати доктсрінгу до функціі
    return f"Hello, {name}"  #з нового рядка і замість прінт треба щоб функція повертала щось


def add_episods(n1,n2):  #змінила назву функціі, бо "add" небажано використовувати
    return n1 + n2  #ретьорн з нового рядка, потрібні пробіли навколо оператора
    

x = 5  #тут не потрібна крапка з комою 
y = 3  #нова змінна з нового рядка

print(greet("John"))  # Виводимо привітання
print(add_episods(x, y))  # Виводимо суму  #для кращого читання потрібний пробіл після коми
# Out:
# Hello, John
# 8

# %% [markdown]
# Завдання 2.

# %%
from math import *
def calcArea(r):return pi*r**2
def calcCircumference(r):return 2*pi*r

radius=5
print("Area:",calcArea(radius),"Circumference:",calcCircumference(radius))
# Out:
# Area: 78.53981633974483 Circumference: 31.41592653589793

# %%
from math import pi  #додала +1 рядок для кращого наглядного читання, імпортуємо не все "*", але лише те що використовуємо

def calc_area(r):
    """Повертає площу кола за заданним радіусом"""  #додали докстрінги
    return pi * r**2  #ретьорн з нового рядка, між функціями 2 рядочки для розділення, між операторами пробіл, за винятком піднесення до степеня


def calc_сircumference(r):
    return 2 * pi * r

radius = 5  #між операторами пробіл
print("Area:", calc_area(radius), "Circumference:", calc_сircumference(radius))
# Out:
# Area: 78.53981633974483 Circumference: 31.41592653589793

# %% [markdown]
# Завдання 3.

# %%
class animal: pass
class dog(animal):
    def __init__(self,name):
        self.name=name
        self.type='Dog'

# %%
class Animal:  #назви класів з великої букви
    """Base class for all animals."""  #додано докстрінги
    pass


class Dog(Animal):
    """Represents is a type of animal."""
    
    def __init__(self, name):
        self.name = name  # Додано пробіли навколо оператора
        self.type = "Dog"  # рядкові значення у подвійних лапках за стандартом PEP8

# %% [markdown]
# Завдання 4.

# %%
list=[1,2,3,4,5]
for i in range(len(list)):print(list[i])
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
list_numbers = [1, 2, 3, 4, 5]  #перейменуємо list, додамо рядок для розділення та кращоої наглядності, додаємо пробіл після коми щоб краще спрималося

for number in list_numbers:  #ітерування відразу зі списку
   print(number)  #з нового рядка + пробіли
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# 5.У вас є DataFrame df, що представляє результати тестів студентів з математики, англійської мови та історії. Поточний код обчислює середній бал для кожного студента шляхом ітерації за рядками DataFrame за допомогою iterrows().
#
# Ваше завдання полягає в тому, щоб змінити код так, аби уникнути використання iterrows() і замість цього застосувати більш ефективне та читабельне рішення відповідно до правил, озвучених у лекції. Рефакторинг треба зробити лише частині, де рахуються середні, імпорт і визначення датафрейму лишаємо без змін.

# %%
import pandas as pd

df = pd.DataFrame({
    'student': ['Alice', 'Bob', 'Charlie', 'David'],
    'math_score': [89, 94, 77, 85],
    'english_score': [92, 88, 79, 85],
    'history_score': [84, 92, 81, 89]
})
df
# Out:
#    student  math_score  english_score  history_score
# 0    Alice          89             92             84
# 1      Bob          94             88             92
# 2  Charlie          77             79             81
# 3    David          85             85             89

# %%
averages = []
for _, row in df.iterrows():
    averages.append((row['math_score'] + row['english_score'] + row['history_score']) / 3)

df['average_score'] = averages
averages
# Out:
# [88.33333333333333, 91.33333333333333, 79.0, 86.33333333333333]

# %%
df['average_score']= df[['math_score', 'english_score','history_score']].mean(axis = 1)  #векторизована операція працює швидше, одразу застосовується до дата фрейму з потрібними нам оцінками без зайвих ітерацій.

df['average_score'] = averages
averages
# Out:
# [88.33333333333333, 91.33333333333333, 79.0, 86.33333333333333]

# %% [markdown]
# 6.У Вас є великий DataFrame df, що представляє транзакції продажу в магазині. Цей DataFrame містить понад 1 мільйон рядків і кілька стовпців, зокрема «product_name», «product_category», «product_price» і «transaction_date».
#
# І «product_name», і «product_category» є рядками, що представляють численні, але обмежені унікальні назви продуктів і категорії відповідно.
#
# Напишіть код для ефективного перетворення стовпців «product_name» і «product_category» на категорійний тип для ефективного використання пам’яті.
# Спробуйте вирішити це завдання, мінімізуючи використання пам'яті та зберігаючи читабельність коду. Крім того, виміряйте використання пам’яті до та після перетворення, щоб продемонструвати підвищення ефективності.
#
# Порівняйте кількість памʼяті, яку займає наданий набір даних і новий, створений Вами. В лекції був приклад. В скільки разів менше памʼяті займає новий датафрейм?

# %%
import pandas as pd
import numpy as np

np.random.seed(0)

products = ['apple', 'banana', 'cherry', 'dates', 'elderberry']
categories = ['fruit', 'fruit', 'fruit', 'fruit', 'fruit']

N_ROWS = 10**6
df = pd.DataFrame({
    'product_name': np.random.choice(products, N_ROWS),
    'product_category': np.random.choice(categories, N_ROWS),
    'product_price': np.random.uniform(1, 10, N_ROWS),
    'transaction_date': pd.date_range(start='1/1/2000', periods=N_ROWS, freq='h')
})

before = df.memory_usage(index=False).sum()  #використання пам’яті в байтах
before
# Out:
# 32000000

# %%
# Перетворюємо стовпці в категорійний тип за допомогою pd.Categorical
df['product_name'] = pd.Categorical(df['product_name'])
df['product_category'] = pd.Categorical(df['product_category'])

# Використання пам’яті після оптимізації
memory_after = df.memory_usage(index=False).sum()
memory_after
# Out:
# 18000328

# %%
difference = (1 - memory_after / before) * 100

print(f"Зменшення використання пам’яті на {difference:.2f} відсотків")
# Out:
# Зменшення використання пам’яті на 43.75 відсотків

# %% [markdown]
# 7.В цьому завданні кілька пунктів. Треба виконати усі послідовно.
#     7.1. Завантажте дані у pandas dataframe з файла `ecommerce_data.csv`. Обовʼязково при завантаженні вкажіть параметр `encoding = 'ISO-8859-1'`, без нього буде помилка.
#     7.2. Заповніть пропущені значення в колонці CustomerID на -1 та перетворіть тип цієї колонки на str, адже зараз вона типу float, а це не правильний тип даних для ідентифікатора клієнта.
#     7.3. З допомогою бібліотеки sweetviz побудуйте html звіт, який порівнює дані для країни "Germany" і країни "France". У Вас можуть виникнути багато попереджень (Warning), їх рекомендую вимкнути наступним шматком коду
#
#
#     import warnings
#
#     with warnings.catch_warnings(record=True):
#         # your code
#
#
#    7.4.Напишіть 5 відмінностей для двох зазначених країн на основі побудованого звіту, без виконання додаткового аналізу іншими інструментами.

# %%
import numpy as np
import pandas as pd

# %%
import os
os.getcwd()
# Out:
# '/Users/mariaslovinska/Desktop/data lovers/Чистий код та оптимізація'

# %%
file_path = "Чистий код та оптимізація/ecommerce_data.csv"

# %%
ls
# Out:
# Lecture_7_1_Clean_code.ipynb
# Lecture_7_2_Огляд_PandasAI.ipynb
# Lecture_7_6_Бібліотеки_для_швидкого_аналізу.ipynb
# ecommerce_data.csv
# hw_7_1_Чистий_код.ipynb

# %%
os.path.exists('ecommerce_data.csv')
# Out:
# True

# %%
df = pd.read_csv('ecommerce_data.csv', encoding = 'ISO-8859-1')

# %%
df.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.dtypes  #глянемо тип даних для кожного стовпця
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
df.isnull().sum()  #кількість пропущених значень для кожного стовпця, ,бачимо що для колонки СustomerID пропущених значень дійсно багато і не можна дісрегард
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# Заповнення пропущених значень в колонці 'CustomerID' на -1
df['CustomerID'] = df['CustomerID'].fillna(-1)

# Перетворення типу колонки 'CustomerID' на str
df['CustomerID'] = df['CustomerID'].astype(str)

# %% [markdown]
# Перевіремо результати наших маніпуляцій:

# %%
print(df['CustomerID'].dtype)
# Out:
# object

# %%
df['CustomerID'].isna().sum()  #перевіримо чи немає вже пустих значень
# Out:
# 0

# %%
pip install sweetviz
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 39.8 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sweetviz as sv
import warnings


with warnings.catch_warnings(record=True):
    
    df_filtered = df[df['Country'].isin(['Germany', 'France'])]   # Фільтруємо дані Germany і France
    
    report = sv.analyze(df_filtered)  #генерація звіту
    report.show_html('country_comparison_report.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report country_comparison_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
# 0:122: execution error: Файл певний обʼєкт не знайдено. (-43)

# %% [markdown]
# Спробуємо ще метод compare

# %%
# Фільтруємо дані для країн Germany та France
df_germany = df[df['Country'] == 'Germany']
df_france = df[df['Country'] == 'France']

# Генерація звіту порівняння
compare_report = sv.compare([df_germany, "Germany"], [df_france, "France"])

compare_report.show_html("compare_germany_vs_france.html")
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report compare_germany_vs_france.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
# 0:122: execution error: Файл певний обʼєкт не знайдено. (-43)

# %% [markdown]
# 1. більше даних по Німеччині, розмір дата фрейму більший
# 2. розглянувши Асоціації можна зробити висновок про відсутність кореляції між UnitPrise та Country в обох країнах
# 3. UnitPrice: MOST FREQUENT VALUES у Німечинні 1025$, у Франції 826$
# 4. Розглядаючи Quantity Мінімальна кількість товарів — мінусові значення можуть вказувати на помилки, пов'язані з поверненнями товарів.
# 5. Кількість товарів у Німечинні продано більше, середнє значення у двох країнах рівне між собою і дорівнює 10, а максималльна ціна (UnitPrice) у Франції становить 4161$, а у  Німечинні 600$

# %% [markdown]
# 8.З допомогою ChatGPT виявіть, чи є та які помилки в наступному коді.
# Попросіть після цього переписати код із дотриманням PEP8. Проаналізуйте результат. Чи справді ChatGPT виправив всі стилістичні помилки? Якщо ні, напишіть йому ще кілька запитів, аби код відповідав вимогам PEP8.
# Вставте фінальну версію коду з чату у ноутбук та запустіть на заданому списку. Має вертатись 50.
# Напишіть, які промпти (інструкції) при зверненні до ChatGPT ви застосували та додайте скріншот(-и) з промптами та відповідями чата.
# Якщо зробили висновки при виконанні цього завдання, то діліться також :)
#
# **ЯК ВСТАВИТИ СКРІНШОТ в Jupyter Notebook** :
# 1. Створіть нову Markdown клітинку
# 2. В новоствореній клітинці обираєте в меню Jupyter Notebook Edit -> Insert Image
# 3. Обираєте картинку
# 4. В клітинці має зʼявитись текст, який містить картинку. Запустіть клітинку.
#
# Або можна просто перетягнути картинку в Markdown клітинку.

# %%
def CalculateVariance(nl):
    sum_list = 0
    for n in nl:
        sum_list = sum_list + n
    mean = sum_list / len(nl)
    sum_squares = 0
    for n in nl:
        sum_squares = sum_squares + n**2
    mean_squares = sum_squares / len(nl)
    return mean_squares

# %%
input_list = [75, 80, 85, 90, 95]

# %%
def calculate_variance(nl):
    """
    Обчислює дисперсію для списку чисел.

    Параметри:
    nl (list): Список чисел для обчислення дисперсії.

    Повертає:
    float: Дисперсія списку чисел або повідомлення про помилку, якщо список порожній.
    """
    if len(nl) == 0:
        return "Список не може бути порожнім"
    
    sum_list = 0
    for n in nl:
        sum_list += n
    
    mean = sum_list / len(nl)
    
    sum_squares = 0
    for n in nl:
        sum_squares += (n - mean) ** 2
    
    variance = sum_squares / len(nl)
    return variance


input_list = [75, 80, 85, 90, 95]
print(calculate_variance(input_list))
# Out:
# 50.0

# %% [markdown]
# ![image.png](attachment:889ca1d1-73f4-44bc-8b80-4f8b1aa91a1f.png)

# %% [markdown]
# ![image.png](attachment:b10295c5-1aec-46db-bffe-846df6e05a67.png)

# %% [markdown]
# ![image.png](attachment:90949168-47f9-4fcc-b65c-ce65c64379e9.png)

# %% [markdown]
# ![image.png](attachment:8a655046-9a47-4c2b-afd5-b474b17e27c0.png)

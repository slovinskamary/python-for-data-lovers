# %% [markdown]
# В цьому ДЗ ми потренуємось будувати візуалізації з використанням бібліотеки `maplotlib` для візуалізації даних в `pandas.DataFrame`.

# %% [markdown]
# # Опис бізнес задачі та набору даних
#
# Набір даних "Yulu" містить інформацію про попит на спільні електровелосипеди в Індії, що надаються провідним індійським постачальником мікромобільності Yulu. Ця компанія пропонує унікальні транспортні засоби для щоденних поїздок з метою усунення транспортних заторів в Індії та забезпечення безпечного, зручного та доступного рішення для пересування. Зони Yulu розташовані в оптимальних місцях, включаючи станції метро, автобусні зупинки, офісні простори, житлові райони та корпоративні офіси, щоб полегшити поїздки на перші та останні кілометри.
#
# Останнім часом Yulu зіткнулася зі значними зниженнями доходів, тому компанія звернулася до консалтингової фірми з метою зрозуміти, від яких факторів залежить попит на ці спільні електровелосипеди, особливо на індійському ринку.
#
# ### Профіль колонок набору даних:
#
# - **datetime**: дата та час зібрані погодинно
# - **season**: сезон (1: весна, 2: літо, 3: осінь, 4: зима)
# - **holiday**: чи є день святковим (витягнуто з http://dchr.dc.gov/page/holiday-schedule)
# - **workingday**: якщо день не є вихідним або святковим, то позначається як 1, в іншому випадку – 0.
# - **weather**:
#   1. Ясно, Мало хмарно, частково хмарно
#   2. Туман + Хмарно, Туман + Розірвані хмари, Туман + Мало хмарно, Туман
#   3. Легкий сніг, Легкий дощ + Гроза + Розсіяні хмари, Легкий дощ + Розсіяні хмари
#   4. Сильний дощ + Крижані кулі + Гроза + Туман, Сніг + Туман
# - **temp**: температура в градусах Цельсія
# - **atemp**: як відчувається температура в градусах Цельсія
# - **humidity**: вологість
# - **windspeed**: швидкість вітру
# - **casual**: кількість неформальних користувачів
# - **registered**: кількість зареєстрованих користувачів
# - **count**: загальна кількість велосипедів, взятих в оренду, включаючи неформальних та зареєстрованих користувачів

# %% [markdown]
# 0. Імпортуйте бібліотеки `matplotlib.pyplot` та `pandas`

# %%
import numpy as np
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
import os
os.listdir()
# Out:
# ['figure_2.png',
#  'figure_3.png',
#  'figure_1.png',
#  'my_figure.png',
#  'hw_4_3_Робота_з_DataFrame_Діаграма_розсіювання.ipynb',
#  'Lecture_4_Data_Visualisation.ipynb',
#  'hw_4_1_Базові_візуалізації.ipynb',
#  '.ipynb_checkpoints',
#  'hw_4_2_Базові_візуалізації_Продовження.ipynb']

# %% [markdown]
# 1. Завантажте дані з файла `yulu_rental.csv` у pandas.DataFrame `df`.

# %%
os.listdir('../data/')
# Out:
# ['.DS_Store',
#  'health_insurance_cross_sell_prediction.csv',
#  'yulu_rental.csv',
#  'supermarket_sales.csv']

# %%
data_path = '../data/yulu_rental.csv'
df = pd.read_csv(data_path)
df.head(3)
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32

# %% [markdown]
# 2. Виведіть
#
# - перші 3 записи з набору даних
# - типи даних в наборі даних
# - розміри набору даних

# %%
df.dtypes
# Out:
# datetime       object
# season          int64
# holiday         int64
# workingday      int64
# weather         int64
# temp          float64
# atemp         float64
# humidity        int64
# windspeed     float64
# casual          int64
# registered      int64
# count           int64
# dtype: object

# %%
df.shape
# Out:
# (10886, 12)

# %% [markdown]
# Перетворимо колонку `datetime` на тип даних `pd.datetime` - це нам доопоможе в подальшій роботі. Просто запустіть колонку нижче і занатуйте собі цей метод роботи з колонкою, в якій міститься дата і час.
# Наша колонка тепер стане таймпстемпом і для неї став доступний функціонал, описаний тут
#
# https://pandas.pydata.org/docs/reference/api/pandas.Timestamp.html
#
# Наприклад, ми можемо легко виокремити дату, день тижня, чи це робочий день, чи ні.

# %%
df['datetime'] = pd.to_datetime(df.datetime)

# %%
df.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %% [markdown]
# 3. З допомогою matplotlib побудуйте найпростіший лінійний графік кількості зареєстрованих користувачів (`registered`) на кожну годину.

# %%
df.plot(
    x='datetime', 
    y='registered', 
    
    title='Кількість зареєстрованих користувачів за годину', 
    figsize=(10, 6)
)
# Out:
# <Axes: title={'center': 'Кількість зареєстрованих користувачів за годину'}, xlabel='datetime'>

# %% [markdown]
# Має вийти щось таке:
# ![](https://drive.google.com/uc?export=view&id=1WX6s9qmiwq_1TSHQtRX0bPL8sT6Gw2BH)

# %% [markdown]
# 4. Графік виглядає так собі, правда? Давайте загрегуємо дані по дням. Для цього запустіть наступний код аби створити колонку "дата" (без часу) і після цього напишіть самостійно код, аби загрегувати дані і отримати кількість зарестрованих клієнтів на день. Ваша фінальна структура (запишіть її в змінну `df_registered_by_date`) даних має містити дві колонки: дату і кількість зареєстрованих користувачів на цей день.

# %%
df['date'] = df.datetime.dt.date

# %%
# Агрегування даних для отримання кількості зареєстрованих користувачів на день
df_registered_by_date = df.groupby('date', as_index=False)['registered'].sum()
df_registered_by_date.rename(columns={'registered': 'total_registered'}, inplace=True)
df_registered_by_date
# Out:
#            date  total_registered
# 0    2011-01-01               654
# 1    2011-01-02               670
# 2    2011-01-03              1229
# 3    2011-01-04              1454
# 4    2011-01-05              1518
# ..          ...               ...
# 451  2012-12-15              4280
# 452  2012-12-16              3248
# 453  2012-12-17              4373
# 454  2012-12-18              5124
# 455  2012-12-19              4934
#
# [456 rows x 2 columns]

# %% [markdown]
# Очікуваний результат:
#
# ![](https://drive.google.com/uc?export=view&id=1DL7Y-R7_CBWNlQNAnMyAoU8hR2MdF5v7)

# %% [markdown]
# 5. Тепер побудуйте лінійний графік з matplotlib для даних в `df_registered_by_date`.
#
#   Додайте наступну частину до графіку аби зробити підписи за віссю ОХ більш читаємими
#
#   `plt.xticks(rotation=45, ha='right')`
#
#   Після побудови графіку проаналізуйте його та напишіть, які тенденції щодо зміни кількості зареєстрованих користувачів в часі ви бачите і чому так може бути?

# %%
df_registered_by_date.plot(
    x='date',
    y='total_registered',
    title='Кількість зарестрованих клієнтів на день', 
    figsize=(10, 6)
);

plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.legend();

plt.show()

# %% [markdown]
# Починаючи з 04-2012 ми спостерігаємо різкий ріст зареєстрованих користувачів. Це може бути результам вдалої маркетингової політики.

# %% [markdown]
# 6. Побудуйте графік розсіювання (scatterplot) між температурою і тим, як вона відчувається (atemp). Поставте прозорість точок 0.2. Додайте підписи до осей Х ат У. Опишіть свої спостереження з цього графіку. Які висновки можна зробити? Що дивного бачите?

# %%
col_x = 'temp'  # Температура
col_y = 'atemp'  # Як температура відчувається
col_c = 'registered'  # Кількість зареєстрованих користувачів

plt.figure(figsize=(8,4))

# Створення графіку розсіювання з кольоровими точками на основі кількості зареєстрованих користувачів
plt.scatter(df[col_x], df[col_y], alpha=0.2, c=df[col_c], cmap='viridis', s=60)

# Підписи осей
plt.xlabel('Температура (temp)')
plt.ylabel('Як температура відчувається (atemp)')

# Додавання кольорової шкали для кількості зареєстрованих користувачів
plt.colorbar(label='Кількість зареєстрованих користувачів')
plt.grid() #cіточка для кращої наглядності
# Показати графік
plt.tight_layout()
plt.show()

# %% [markdown]
#   Очікуваний графік:
# ![](https://drive.google.com/uc?export=view&id=13Mi6AGPUh5aQ5YEZjrlkQPuFcNzeeppB)

# %% [markdown]
# Чим теплішою відчувається погода - тим зростає кількість реєстрацій (відмічаємо орієнтовно від 25 до 35+ градусів), далі після 35 градусів ця тенденція йде на спад. Висновок - наш бізнес сезонний і варто "дружити" з метеоролагами та краще ставити свічку за теплу, але неспекотну погоду))) Жартую. Дивно - пряма з точок, яка паралельна осі x з 25 до 35+градусів - може свідчити про якусь нетиповість або неточність данних у датафреймі?
